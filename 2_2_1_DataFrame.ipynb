# %% [markdown]
# <a href="https://colab.research.google.com/github/cjguajardo/diplomado-bads/blob/main/2_2_1_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **1. Trabajando con DataFrame.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
studentsHeader = ['nota', 'genero', 'asistencia']
df_students = pd.read_csv('https://drive.usercontent.google.com/download?id=1dWLl-YGn_6plDbNmGuqNz_XClnkmTfJ7&export=download&authuser=0', sep=',', header=None, names=studentsHeader)
df_students
# Out:
#      nota  genero  asistencia
# 0     4.7     0.0         0.1
# 1     3.9     1.0         0.3
# 2     1.5     0.0         0.0
# 3     5.0     0.0         0.1
# 4     3.9     0.0         0.9
# ..    ...     ...         ...
# 995   6.2     0.0         0.1
# 996   6.3     0.0         0.1
# 997   6.7     0.0         0.3
# 998   7.0     0.0         0.8
# 999   4.2     0.0         0.3
#
# [1000 rows x 3 columns]

# %%
df_students.groupby("genero").size()
# Out:
# genero
# 0.0    505
# 1.0    495
# dtype: int64

# %%
df_students.groupby('nota').size()
# Out:
# nota
# 1.0    10
# 1.1    18
# 1.2    19
# 1.3    18
# 1.4    14
#        ..
# 6.6    16
# 6.7    12
# 6.8    13
# 6.9    11
# 7.0     7
# Length: 61, dtype: int64

# %%
df_students.describe()
# Out:
#               nota       genero   asistencia
# count  1000.000000  1000.000000  1000.000000
# mean      3.978800     0.495000     0.505800
# std       1.748407     0.500225     0.297144
# min       1.000000     0.000000     0.000000
# 25%       2.400000     0.000000     0.200000
# 50%       3.900000     0.000000     0.500000
# 75%       5.600000     1.000000     0.800000
# max       7.000000     1.000000     1.000000

# %%
d_genero = { 0: 'Femenino', 1: 'Masculino'}

# %%
df_students['desc_genero'] = df_students['genero'].map(d_genero)

# %%
df_students
# Out:
#      nota  genero  asistencia desc_genero
# 0     4.7     0.0         0.1    Femenino
# 1     3.9     1.0         0.3   Masculino
# 2     1.5     0.0         0.0    Femenino
# 3     5.0     0.0         0.1    Femenino
# 4     3.9     0.0         0.9    Femenino
# ..    ...     ...         ...         ...
# 995   6.2     0.0         0.1    Femenino
# 996   6.3     0.0         0.1    Femenino
# 997   6.7     0.0         0.3    Femenino
# 998   7.0     0.0         0.8    Femenino
# 999   4.2     0.0         0.3    Femenino
#
# [1000 rows x 4 columns]

# %%
df_students.groupby('desc_genero').size()
# Out:
# desc_genero
# Femenino     505
# Masculino    495
# dtype: int64

# %%
df_students.describe()
# Out:
#               nota       genero   asistencia
# count  1000.000000  1000.000000  1000.000000
# mean      3.978800     0.495000     0.505800
# std       1.748407     0.500225     0.297144
# min       1.000000     0.000000     0.000000
# 25%       2.400000     0.000000     0.200000
# 50%       3.900000     0.000000     0.500000
# 75%       5.600000     1.000000     0.800000
# max       7.000000     1.000000     1.000000

# %%
df_students.head(10)
# Out:
#    nota  genero  asistencia desc_genero
# 0   4.7     0.0         0.1    Femenino
# 1   3.9     1.0         0.3   Masculino
# 2   1.5     0.0         0.0    Femenino
# 3   5.0     0.0         0.1    Femenino
# 4   3.9     0.0         0.9    Femenino
# 5   4.0     0.0         0.9    Femenino
# 6   2.9     0.0         0.4    Femenino
# 7   1.8     0.0         0.1    Femenino
# 8   1.8     0.0         0.6    Femenino
# 9   1.2     0.0         0.4    Femenino

# %%
df_students.columns
# Out:
# Index(['nota', 'genero', 'asistencia', 'desc_genero'], dtype='object')

# %%
pd.unique(df_students['nota'])
# Out:
# array([4.7, 3.9, 1.5, 5. , 4. , 2.9, 1.8, 1.2, 3. , 2.4, 1.3, 6.5, 3.7,
#        5.4, 4.4, 5.2, 2.2, 3.3, 5.1, 4.1, 4.8, 4.3, 2.7, 6.2, 4.5, 3.1,
#        6. , 5.9, 2.8, 6.3, 1.1, 5.6, 3.2, 6.9, 1.6, 3.6, 2. , 2.3, 6.8,
#        5.3, 5.8, 5.5, 1.9, 6.6, 6.1, 6.7, 7. , 3.4, 3.8, 6.4, 4.6, 1.7,
#        2.6, 3.5, 2.5, 1.4, 2.1, 1. , 5.7, 4.2, 4.9])

# %% [markdown]
# ### **1.1. Diferencias entre len() y nunique().**

# %%
lstNotas = df_students['nota']
lstNotas
# Out:
# 0      4.7
# 1      3.9
# 2      1.5
# 3      5.0
# 4      3.9
#       ...
# 995    6.2
# 996    6.3
# 997    6.7
# 998    7.0
# 999    4.2
# Name: nota, Length: 1000, dtype: float64

# %%
print(len(lstNotas))
print(df_students['nota'].nunique())
# Out:
# 1000
# 61

# %%
print("Max :", df_students['nota'].max())
print("Min :", df_students['nota'].min())
print("Promedio :", df_students['nota'].mean())
print("Desviación estándar :", df_students['nota'].std())
print("Count :", df_students['nota'].count())
# Out:
# Max : 7.0
# Min : 1.0
# Promedio : 3.9788
# Desviación estándar : 1.7484071286423786
# Count : 1000

# %%
grupo_genero = df_students.groupby('desc_genero')
grupo_genero.describe()
# Out:
#               nota                                              genero       \
#              count      mean       std  min  25%  50%  75%  max  count mean
# desc_genero
# Femenino     505.0  3.967129  1.777513  1.0  2.3  4.0  5.5  7.0  505.0  0.0
# Masculino    495.0  3.990707  1.719922  1.0  2.5  3.9  5.6  7.0  495.0  1.0
#
#              ...           asistencia                                          \
#              ...  75%  max      count      mean       std  min  25%  50%  75%
# desc_genero  ...
# Femenino     ...  0.0  0.0      505.0  0.498416  0.291747  0.0  0.3  0.5  0.7
# Masculino    ...  1.0  1.0      495.0  0.513333  0.302660  0.0  0.2  0.5  0.8
#
#
#              max
# desc_genero
# Femenino     1.0
# Masculino    1.0
#
# [2 rows x 24 columns]

# %%
# Regresa la media de cada columna numérica por genero
grupo_genero.mean()
# Out:
#                  nota  genero  asistencia
# desc_genero
# Femenino     3.967129     0.0    0.498416
# Masculino    3.990707     1.0    0.513333

# %%
df_students.dtypes
# Out:
# nota           float64
# genero         float64
# asistencia     float64
# desc_genero     object
# dtype: object

# %%
df_students.shape
# Out:
# (1000, 4)

# %%
df_students.tail()
# Out:
#      nota  genero  asistencia desc_genero
# 995   6.2     0.0         0.1    Femenino
# 996   6.3     0.0         0.1    Femenino
# 997   6.7     0.0         0.3    Femenino
# 998   7.0     0.0         0.8    Femenino
# 999   4.2     0.0         0.3    Femenino

# %%
avg_by_gender = df_students.groupby('desc_genero')['nota'].mean()
avg_by_gender
# Out:
# desc_genero
# Femenino     3.967129
# Masculino    3.990707
# Name: nota, dtype: float64

# %%
# Agrupar por genero y obtener la nota maxima
result = df_students.groupby('desc_genero')['nota'].max()
result
# Out:
# desc_genero
# Femenino     7.0
# Masculino    7.0
# Name: nota, dtype: float64

# %%
# Agrupar por genero y obtener la nota minima
result = df_students.groupby('desc_genero')['nota'].min()
result
# Out:
# desc_genero
# Femenino     1.0
# Masculino    1.0
# Name: nota, dtype: float64

# %%
# Agrupar por genero y obtener la media de las notas
mean_grades_by_gender = df_students.groupby('desc_genero')['nota'].mean()
print(mean_grades_by_gender)
# Out:
# desc_genero
# Femenino     3.967129
# Masculino    3.990707
# Name: nota, dtype: float64

# %%
# Agrupar por género y contar la cantidad de estudiantes en cada grupo
gender_counts = df_students.groupby('desc_genero').size()

# Crear el gráfico de torta
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Asegurar que el gráfico sea un círculo
plt.title('Distribución de Géneros')
plt.show()

# %%
grades_counts = df_students.groupby('nota').size()

# Crear el gráfico de barras
plt.bar(grades_counts.index, grades_counts.values)
plt.xlabel("Nota")
plt.ylabel("Count")
plt.title("Distribución de Notas")
plt.show()

# %%
repitentes = df_students[df_students['nota'] < 4]

# segmenta por genero
repitentes.groupby('desc_genero').size().plot(kind='bar', title='Repitentes por Género')
plt.xlabel('Género')
plt.show()

# %%
# Distribución de repitentes por género
repitentes.groupby('desc_genero').size().plot(kind='bar', title='Repitentes por Género')
plt.xlabel('Género')
plt.show()

# %%
# Distribución de asistencia por genero
df_students.groupby('desc_genero').size().plot(kind='bar', title='Asistencia por Género')
plt.xlabel('Género')
plt.show()

# %%
# Segmentación de estudiantes por asistencia
asist_segment = pd.cut(df_students['asistencia'], bins=[0, .7, 1], labels=['Bajo', 'Alto'])
# grafico
asist_segment.value_counts().plot(kind='bar', title='Asistencia por Género')
plt.xlabel('Género')
plt.show()

# %%
# Distribución por genero de estudiantes con asistencia bajo 70%
df_students[df_students['asistencia'] <= 0.7].groupby('desc_genero').size().plot(kind='bar', title='Asistencia por Género')
plt.xlabel('Género')
plt.show()

# %%
df_students['asistencia'] = df_students['asistencia']*100
X = df_students.drop(['desc_genero','asistencia'],axis=1)
y = df_students['asistencia']

print("X: ",X.shape)
print("y: ", y.shape)
print(X.head())
print(y.head())
print(df_students.head())
# Out:
# X:  (1000, 2)
# y:  (1000,)
#    nota  genero
# 0   4.7     0.0
# 1   3.9     1.0
# 2   1.5     0.0
# 3   5.0     0.0
# 4   3.9     0.0
# 0    10.0
# 1    30.0
# 2     0.0
# 3    10.0
# 4    90.0
# Name: asistencia, dtype: float64
#    nota  genero  asistencia desc_genero
# 0   4.7     0.0        10.0    Femenino
# 1   3.9     1.0        30.0   Masculino
# 2   1.5     0.0         0.0    Femenino
# 3   5.0     0.0        10.0    Femenino
# 4   3.9     0.0        90.0    Femenino

# %%
plt.figure(figsize=(10,10))
p=sns.heatmap(X.corr(), annot=True, cmap='RdYlGn', square=True)

# %% [markdown]
# No hay correlación de las variable

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Se separan las variables predictoras y la predictiva
x = df_students[['nota','genero']] # Variables independientes
y = df_students['asistencia'] # Variable dependiente

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.8, random_state=29)

# Tipo de modelo
modelo = LinearRegression()

# Entrenamiento del modelo
modelo.fit(X_train, y_train)

# Validación del modelo
y_pred = modelo.predict(X_test)

# Evaluación del modelo
print("R2 :%.2f" % r2_score(y_test, y_pred))
# print("MSE: %.2f" % mean_squared_error(y_pred, y_test))
print("Score del modelo : %.2f" % modelo.score(X_train, y_train))
# Out:
# R2 :-0.00
# Score del modelo : 0.00
